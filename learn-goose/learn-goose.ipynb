# %%
from goose3 import Goose
from goose3.text import StopWordsChinese
# 初始化，设置中文分词
g = Goose({'stopwords_class': StopWordsChinese})
# 文章地址
url = 'https://mp.weixin.qq.com/s/zflbcF5PS06QC5YJXpiviQ'
# 获取文章内容
article = g.extract(url=url)
# 标题
print('标题：', article.title)
# 显示正文
print(article.cleaned_text)
# Out:
# 标题： 如何用Python抓抖音上的小姐姐
# 爬虫的案例我们已讲得太多。不过几乎都是网页爬虫。即使有些手机才能访问的网站，我们也可以通过 Chrome 开发者工具的手机模拟功能来访问，以便于分析请求并抓取。（比如 3分钟破译朋友圈测试小游戏 文章里用的方法）
#
#
#
# 但有些 App 根本就没有提供网页端，比如今年火得不行的抖音。（网上有些教程也是用网页手机模拟的方法，但此法现已失效。）
#
# 手机 App 不像电脑上的网页能直接通过浏览器查看相关信息，在手机设备上也不方便使用工具一边流量一边调试。所以常用的方式就是通过在电脑上装一些“抓包”软件，将手机上的网络请求全部显示出来。
#
# 那为什么电脑能看到手机上的网络请求？这里就要提下“代理”这个概念。我们之前的文章 听说你好不容易写了个爬虫，结果没抓几个就被封了？ 中也讲过代理。形象的解释就是字面的理解：所有你发出的请求不再是直接发到目的地，而是先发给这个代理，再由代理帮你发出。所以通过代理，可以实现隐藏 IP、进入专用网络、翻…咳咳那啥等功能，也包括我们今天说的：手机抓包。
#
# 顺带说句，在公共场所别随便连不确定的免费 wifi，理论上来说，人家也可以抓你的包。
#
# 这里，我们要用的工具是 Fiddler。它是一个较成熟的免费抓包工具。可以抓取网页、桌面软件、手机 App 的网络请求，并可以运行在 Windows、Mac、Linux 平台上，支持 iOS 和 Android。（虽说都支持，但强烈建议 Windows + Android，后面我会有吐槽）
#
#
#
# 上周我们的送书活动收到不少同学的项目和代码，其中 @离岛 同学提交了一个 Fiddler 手机抓包的教程。
#
# https://segmentfault.com/a/1190000015571256
#
# 本文中部分内容和图片就转自她这篇文章。她的博客上还有不少文章和学习笔记，可以关注交流。也欢迎其他同学给我们投稿。
#
# 搜索一下 fiddler 很容易找到它们的官网 https://www.telerik.com/fiddler，点击 download 下载即可（有个表格随便填下）。
#
# Windows 下载后正常安装。如果是 Mac，还会有安装步骤提示，告诉你需要先安装一个叫做 Mono 的框架，以便可以执行 Fiddler.exe。另外 Mac 版还有几个小坑：
#
# 3. 第一次正确运行时，程序会卡住很长时间，以至于我以为还是挂了，这时请耐心等待。（我要不是正好有事走开，回来发现成功了，可能就放弃尝试了）
#
# 4. 即使正常运行了，Mac 上界面也会有各种显示的 bug，切记不要打开的弹窗的情况下切换程序，不然回来就找不到弹窗了……
#
# 6. 在 iOS 上无法抓取 HTTPS 请求（这基本就是废了），需要额外创建一个证书，但这个证书工具只能在 Windows 下运行……
#
# 所以可以的话，还是用 Windows 来做。Mac 上还有个比较知名的工具 Charles，有用过的可以留言评价下。
#
# 设置允许抓取 HTTPS 信息包。打开下载好的 fiddler，找到 Tools -> Options，然后在 HTTPS 的工具栏下勾选 Decrpt HTTPS traffic，在新弹出的选项栏下勾选 Ignore server certificate errors。这样，fiddler 就会抓取到 HTTPS 的信息包。
#
# 设置允许外部设备发送 HTTP/HTTPS 到 fiddler。设置端口号，并在 Connections 选项栏下勾选 Allow remote computers to connect。
#
# 在抓包前，确保你的电脑和手机是在一个可以互访的局域网中。最简单的情况就是都连在同一个 wifi 上，特殊情况这里不展开讨论（有些商用 wifi 并不能互访）。
#
# 打开软件，鼠标放在右上角的 Online 上可以看到本机的 IP。或者也可以通过命令行中的 ipconfig 命令（Mac/Linux 是 ifconfig）查看。（截图仅为演示，以你自己的 IP 为准）
#
# 手机设置代理 IP。打开手机无线网络连接，选择已经连接的网络连接，点击一个小圆圈叹号进入可以看到下图（安卓也类似），选择配置代理，进入后把刚刚的 IP 地址输入进去，端口就是 fiddler 中设置的 8888。
#
#
#
# 手机访问前面设置的电脑的 IP 地址加端口 8888 访问，比如图中例子是：http://192.168.23.1:8888
#
#
#
# 开启 fiddler 的状态下，打开手机随便一个 APP，应对可以正常访问，并且在 fiddler 中看到所发出的网络请求。
#
# 如果能访问但看不到请求，确认下有没有代理有没有生效。如果不能访问，检查下证书是否都下载并验证。还是不行则按照上述步骤再仔细配置一遍。
#
#
#
# 完成这一步之后，接下来的事情就和网页爬虫没太大区别了。无非就是从这些请求中，找到我们需要的那几个。
#
# fiddler 里记录的是所有请求，比较多。在操作 App 前，记得清空已有请求，方便观察。然后再配合上 filter 筛选器，定义筛选规则，会较容易找你需要的内容。找到请求后，在软件里查看你要的信息，或者右键点击选择将请求导出。
#
# 经过操作+观察，可以定位到获取用户上传视频列表的请求是
#
# https://api.amemv.com/aweme/v1/aweme/post/?…
#
# 从 WebForms 栏里可以查看请求的详细参数信息。返回值是一个组 JSON 数据，里面包含了视频的下载地址。
#
#
#
# 这是一个需要经验积累的活儿，不同的网站/App，规则都不一样，但套路是相似的。对网页爬虫还不熟悉的话，先看看之前的文章 爬虫必备工具，掌握它就解决了一半的问题。
#
#
#
# 得到地址之后，经过在浏览器和代码里的一番尝试，找到了此请求的正确解锁方式：
#
# 1. 需要提供以下参数： ，其中 user_id 是你要抓取的用户 ID，其他参数都可以固定不用改。
#
# 2. 需要使用手机的 User-Agent，最简单的就是
#
# uid 替换成你想抓的用户 ID。获取用户 ID 有个简单方法：在用户页面选择分享，链接发到微信上，从网页打开就可以看到 user_id。
#
# 此方法截止中秋假期还是有效的，可以通过 Chrome 开发者工具进行模拟。之后能使用多久这就没法保证了，爬虫代码都不会是一劳永逸的。
#
#
#
# 总结下，重点是 fiddler 的抓取，关键是 配置、代理、证书，难点是 对请求的分析。最终代码只有简单两步，获取视频列表、下载视频。
#
# 所有代码其实就上面两段，也上传了，获取地址请在公众号（Crossin的编程教室）回复关键字 抖音
#
# 想看其他十多个项目代码实例（电影票、招聘、贪吃蛇、代理池等），回复关键字 项目
#
# 请把我们分享给身边爱学习的小伙伴 :)

# %%
url = 'http://edition.cnn.com/2012/02/22/world/europe/uk-occupy-london/index.html?hpt=ieu_c2'
g = Goose({
    'browser_user_agent': 'Version/5.1.2 Safari/534.52.7',
    'http_timeout': 15
})
article = g.extract(url=url)
print(article.meta_description)
print(article.meta_keywords)
print(article.tags)
print(article.top_image)
print(article.infos)
print(article.raw_html)
# Out:
# Occupy London protesters who have been camped outside the landmark St. Paul's Cathedral for the past four months lost their court bid to avoid eviction Wednesday in a decision made by London's Court of Appeal.
# europe, Occupy London loses eviction fight - CNN
# []
# None
# {'opengraph': {'site_name': 'CNN', 'image:height': '259', 'image:width': '460', 'image': 'https://cdn.cnn.com/cnnnext/dam/assets/111017024308-occupy-london-st-paul-s-cathedral-story-top.jpg', 'url': 'https://edition.cnn.com/2012/02/22/world/europe/uk-occupy-london/index.html', 'pubdate': '2012-02-22T10:37:52Z', 'type': 'article', 'description': "Occupy London protesters who have been camped outside the landmark St. Paul's Cathedral for the past four months lost their court bid to avoid eviction Wednesday in a decision made by London's Court of Appeal."}, 'cleaned_text': 'Occupy London protesters who have been camped outside the landmark St. Paul\'s Cathedral for the past four months lost their court bid to avoid eviction Wednesday in a decision made by London\'s Court of Appeal.\n\nLast month, the High Court ruled in favor of the City of London Corporation, the body that runs London\'s financial district, which applied for an eviction order after the protesters failed to abide by a previous order to pack up the camp.\n\nThe Occupy London group then filed an appeal against the ruling at the Court of Appeal.\n\nWednesday, the three judges of the court refused them the permission to appeal.\n\nMichael Paget, the lawyer representing the Occupy London group, said the group doesn\'t intend to file another legal challenge.\n\n"The occupy message has been heard and will continue to be heard. It has made a difference and will continue to make a difference."\n\nThe activists, who set up camp outside the cathedral October 15, had been protesting against corporate greed and economic inequality.\n\nMany of the tents set up by the Occupy activists around St. Paul\'s are on what the corporation designates as a public road. St. Paul\'s suspended its own legal action against the activists in November, after a number of senior cathedral figures resigned over the threat to evict them.\n\n"Peaceful protest is a democratic right but the camp is clearly in breach of highway and planning law," said Stuart Fraser, policy chairman for the City of London Corporation." I would call on protesters to comply with the decision of the courts and remove their tents and equipment voluntarily right away."', 'movies': [], 'domain': 'edition.cnn.com', 'image': None, 'links': ['javascript:void(0);', '/videos'], 'title': 'Occupy London loses eviction fight', 'meta': {'encoding': 'utf-8', 'favicon': '/favicon.ie9.ico', 'lang': None, 'description': "Occupy London protesters who have been camped outside the landmark St. Paul's Cathedral for the past four months lost their court bid to avoid eviction Wednesday in a decision made by London's Court of Appeal.", 'canonical': 'https://edition.cnn.com/2012/02/22/world/europe/uk-occupy-london/index.html', 'keywords': 'europe, Occupy London loses eviction fight - CNN'}, 'publish_date': None, 'tags': [], 'authors': [], 'tweets': []}
# <!DOCTYPE html><html class="no-js"><head><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"><meta charset="utf-8"><meta content="text/html" http-equiv="Content-Type"><meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0"><link rel="dns-prefetch" href="//cdn.optimizely.com/js/128727546.js" /><link rel="dns-prefetch" href="//tpc.googlesyndication.com" /><link rel="dns-prefetch" href="//pagead2.googlesyndication.com" /><link rel="dns-prefetch" href="//www.googletagservices.com" /><link rel="dns-prefetch" href="//partner.googleadservices.com" /><link rel="dns-prefetch" href="//www.google.com" /><link rel="dns-prefetch" href="//aax.amazon-adsystem.com" /><link rel="dns-prefetch" href="//c.amazon-adsystem.com" /><link rel="dns-prefetch" href="//cdn.krxd.net" /><link rel="dns-prefetch" href="//ads.rubiconproject.com" /><link rel="dns-prefetch" href="//optimized-by.rubiconproject.com" /><link rel="dns-prefetch" href="//fastlane.rubiconproject.com" /><link rel="dns-prefetch" href="//fastlane-adv.rubiconproject.com" /><link rel="dns-prefetch" href="//segment-data-us-east.zqtk.net/turner-47fcf6" /><link rel="dns-prefetch" href="//a.postrelease.com/serve/load.js?async=true" /><link rel="dns-prefetch" href="//w.usabilla.com" /><link rel="dns-prefetch" href="" /><link rel="dns-prefetch" href="//data.api.cnn.io" /><link rel="dns-prefetch" href="//pmd.cdn.turner.com" /><link rel="dns-prefetch" href="//amd.cdn.turner.com" /><link rel="dns-prefetch" href="//ht.cdn.turner.com" /><link rel="dns-prefetch" href="//www.ugdturner.com" /><link rel="dns-prefetch" href="//vrt.outbrain.com" /><link rel="dns-prefetch" href="//consent.truste.com" /><link rel="dns-prefetch" href="//as.casalemedia.com" /><link rel="dns-prefetch" href="//as-sec.casalemedia.com" /><link rel="dns-prefetch" href="//dsum-sec.casalemedia.com" /><link rel="dns-prefetch" href="//js-sec.indexww.com" /><link rel="dns-prefetch" href="//data.cnn.com" /><link rel="dns-prefetch" href="//cdn.cnn.com" /><link rel="dns-prefetch" href="//edition.i.cdn.cnn.com" /><link rel="preload" href="//registry.api.cnn.io/bundles/fave/latest-2.x/css" as="style" type="text/css">
# <link rel="preload" href="/.a/bundles/cnn-header.b34c480d81eee418e62b-first-bundle.js" as="script" type="application/javascript">
# <link rel="preload" href="/.a/2.118.0/js/cnn-header-second.min.js" as="script" type="application/javascript">
# <link rel="preload" href="//cdn.optimizely.com/js/128727546.js" as="script" type="text/javascript">
# <link rel="preload" href="//edition.i.cdn.cnn.com/.a/fonts/cnn/3.7.2/cnnsans-regular.woff2" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="//edition.i.cdn.cnn.com/.a/fonts/icons/2.4.7/cnn-icons.woff2" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="//edition.i.cdn.cnn.com/.a/fonts/cnn/3.7.2/cnnsans-medium.woff2" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="//edition.i.cdn.cnn.com/.a/fonts/cnn/3.7.2/cnnsans-bold.woff2" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="//edition.i.cdn.cnn.com/.a/fonts/cnn/3.7.2/cnnsans-light.woff2" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="//cdn.cnn.com/analytics/cnnexpan/jsmd.min.js" as="script" type="application/x-javascript">
# <link rel="preload" href="/.a/2.118.0/js/cnn-footer-lib.min.js" as="script" type="application/javascript">
# <link rel="preload" href="/.a/2.118.0/js/gigya-sharebar.min.js" as="script" type="application/javascript">
# <link rel="preload" href="/.a/2.118.0/js/cnn-analytics.min.js" as="script" type="application/javascript">
# <link rel="preload" href="//amplify.outbrain.com/cp/obtp.js" as="script" type="application/x-javascript">
# <link href="/favicon.ie9.ico" rel="Shortcut Icon" type="image/x-icon"/><link href="//cdn.cnn.com/cnn/.e/img/3.0/global/misc/apple-touch-icon.png" rel="apple-touch-icon" type="image/png"/><!--[if lte IE 9]><meta http-equiv="refresh" content="1;url=/2.118.0/static/unsupp.html" /><![endif]--><!--[if gt IE 9><!--><!--<![endif]--><title>Occupy London loses eviction fight - CNN</title><meta content="europe" name="section"><meta name="referrer" content="unsafe-url"><meta content="2012-02-22T10:37:52Z" property="og:pubdate"><meta content="2012-02-22T10:37:52Z" name="pubdate"><meta content="2012-02-22T11:10:01Z" name="lastmod"><meta content="https://edition.cnn.com/2012/02/22/world/europe/uk-occupy-london/index.html" property="og:url"><meta content="From Erin McLaughlin , CNN" name="author"><meta content="CNN" name="source"><meta content="Occupy London protesters who have been camped outside the landmark St. Paul&#39;s Cathedral for the past four months lost their court bid to avoid eviction Wednesday in a decision made by London&#39;s Court of Appeal." property="og:description"><meta content="Occupy London protesters who have been camped outside the landmark St. Paul&#39;s Cathedral for the past four months lost their court bid to avoid eviction Wednesday in a decision made by London&#39;s Court of Appeal." name="description"><meta content="Occupy London protesters who have been camped outside the landmark St. Paul&#39;s Cathedral for the past four months lost their court bid to avoid eviction Wednesday in a decision made by London&#39;s Court of Appeal." name="twitter:description"><meta content="europe, Occupy London loses eviction fight - CNN" name="keywords"><meta content="CNN" property="og:site_name"><meta content="summary_large_image" name="twitter:card"><meta content="article" property="og:type"><meta content="https://cdn.cnn.com/cnnnext/dam/assets/111017024308-occupy-london-st-paul-s-cathedral-story-top.jpg" property="og:image"><meta content="460" property="og:image:width"><meta content="259" property="og:image:height"><meta content="https://cdn.cnn.com/cnnnext/dam/assets/111017024308-occupy-london-st-paul-s-cathedral-story-top.jpg" name="thumbnail"><meta content="https://cdn.cnn.com/cnnnext/dam/assets/111017024308-occupy-london-st-paul-s-cathedral-story-top.jpg" name="twitter:image"><link rel="image_src" href="https://cdn.cnn.com/cnnnext/dam/assets/111017024308-occupy-london-st-paul-s-cathedral-story-top.jpg"><meta property="vr:canonical" content="https://edition.cnn.com/2012/02/22/world/europe/uk-occupy-london/index.html"><link rel="alternate" href="https://edition.cnn.com/2012/02/22/world/europe/uk-occupy-london/index.html" hreflang="en-gb"><link rel="alternate" href="https://edition.cnn.com/2012/02/22/world/europe/uk-occupy-london/index.html" hreflang="en"><meta content="80401312489" property="fb:app_id"><meta content="5550296508,18793419640" property="fb:pages"><link rel="canonical" href="https://edition.cnn.com/2012/02/22/world/europe/uk-occupy-london/index.html"><link rel="publisher" href="https://plus.google.com/+cnn/posts" /><link rel="alternate" href="android-app://com.cnn.mobile.android.phone/http/edition.cnn.com/2012/02/22/world/europe/uk-occupy-london/index.html" /><script type="application/ld+json">{"@context": "http://schema.org/", "@type": "WebPage","name": "Occupy London loses eviction fight", "speakable": {"@type": "SpeakableSpecification","cssSelector": [".pg-headline", ".speakable"]}, "url": "https://edition.cnn.com/2012/02/22/world/europe/uk-occupy-london/index.html"}</script><style>@charset "UTF-8";.zn.t-hidden{display:none!important}.m-legal .m-legal__links[data-analytics=footer_adchoices]:after{content:"";display:block;margin:0;padding:0}h1 a,h2 a,h3 a,h4 a,h5 a,h6 a{color:inherit;text-decoration:none}h1 a:visited,h2 a:visited,h3 a:visited,h4 a:visited,h5 a:visited,h6 a:visited{color:inherit}h1 a:hover,h2 a:hover,h3 a:hover,h4 a:hover,h5 a:hover,h6 a:hover{text-decoration:none}.pg.t-dark h1 a:hover,.pg.t ...
# /*# sourceMappingURL=global.css.map */</style><style>@charset "UTF-8";.zn.t-hidden{display:none!important}.metadata:after,.video__end-slate__tertiary .video__end-slate__carousel .cd:after,.zn-staggered:after,.zn:after{clear:both;content:"";display:table}.cn-section-preview.container-middle,.cn-section-preview.container-middle .cd,.cn-section-preview.container-middle .cd__wrapper,.cn-section-preview.container-middle .cn__column,.flexbox .cn-carousel-large-strip .owl-wrapper,.flexbox .cn-carousel-large-strip .owl-wrapper .cd,.flexbox .cn-carousel-large-strip .owl-wrapper .cd__wrapper,.flexbox .cn-carousel-large-strip .owl-wrapper .cn__column,.flexbox .cn-carousel-large-strip .owl-wrapper .owl-item,.flexbox .cn-carousel-large-strip .owl-wrapper .owl-item>[data-slidename],.flexbox .cn-carousel-medium-strip .owl-wrapper,.flexbox .cn-carousel-medium-strip .owl-wrapper .cd,.flexbox .cn-carousel-medium-strip .owl-wrapper .cd__wrapper,.flexbox .cn-carousel-medium-strip .owl-wrapper .cn__column,.flexbox .cn-carousel-medium-strip .owl-wrapper .owl-item,.flexbox .cn-carousel-medium-strip .owl-wrapper .owl-item>[data-slidename],.flexbox .cn-grid .owl-wrapper,.flexbox .cn-grid .owl-wrapper .cd,.flexbox .cn-grid .owl-wrapper .cd__wrapper,.flexbox .cn-grid .owl-wrapper .cn__column,.flexbox .cn-grid .owl-wrapper .owl-item,.flexbox .cn-grid .owl-wrapper .owl-item>[data-slidename]{display:-webkit-flex;display:-webkit-box;display:-ms-flexbox;display:flex}.cn-section-preview.container-middle .cd,.flexbox .cn-carousel-large-strip .owl-wrapper .cd,.flexbox .cn-carousel-medium-strip .owl-wrapper .cd,.flexbox .cn-grid .owl-wrapper .cd{-webkit-flex-direction:column;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;width:100%}.cn-section-preview.container-middle .cd__wrapper,.flexbox .cn-carousel-large-strip .owl-wrapper .cd__wrapper,.flexbox .cn-carousel-medium-strip .owl-wrapper .cd__wrapper,.flexbox .cn-grid .owl-wrapper .cd__wrapper{-webkit-flex-direction:column;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;-webkit-flex-grow:1;-webkit-box-flex:1;-ms-flex-positive:1;flex-grow:1;-webkit-justify-content:space-between;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;width:100%}.cd--tool__feed .cn-section-preview.container-middle .cd-feed__content,.cd--tool__feed .flexbox .cn-carousel-large-strip .owl-wrapper .cd-feed__content,.cd--tool__feed .flexbox .cn-carousel-medium-strip .owl-wrapper .cd-feed__content,.cd--tool__feed .flexbox .cn-grid .owl-wrapper .cd-feed__content,.cn-section-preview.container-middle .cd--tool__feed .cd-feed__content,.cn-section-preview.container-middle .cd__content,.flexbox .cn-carousel-large-strip .owl-wrapper .cd--tool__feed .cd-feed__content,.flexbox .cn-carousel-large-strip .owl-wrapper .cd__content,.flexbox .cn-carousel-medium-strip .owl-wrapper .cd--tool__feed .cd-feed__content,.flexbox .cn-carousel-medium-strip .owl-wrapper .cd__content,.flexbox .cn-grid .owl-wrapper .cd--tool__feed .cd-feed__content,.flexbox .cn-grid .owl-wrapper .cd__content{-webkit-flex:1 1 auto;-webkit-box-flex:1;-ms-flex:1 1 auto;flex:1 1 auto}.flexbox .cn-carousel-large-strip .owl-wrapper .owl-item,.flexbox .cn-carousel-large-strip .owl-wrapper .owl-item>[data-slidename],.flexbox .cn-carousel-medium-strip .owl-wrapper .owl-item,.flexbox .cn-carousel-medium-strip .owl-wrapper .owl-item>[data-slidename],.flexbox .cn-grid .owl-wrapper .owl-item,.flexbox .cn-grid .owl-wrapper .owl-item>[data-slidename]{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:100%}.m-financial__wrapper .m-financial__field .m-financial__field-icon:after,.mycnn-social-settings__network .mycnn-social-settings__social-icon,.pg-vertical--entertainment.pg-leaf .legal a[data-analytics=footer_adchoices]:after,.pg-vertical--entertainment.pg-section .legal a[data-analytics=footer_adchoices]:after,.pg-vertical--entertainment.pg-special .l ...
# /*# sourceMappingURL=page.css.map */</style><style>.zn.t-hidden{display:none!important}.cn-collection-player .cn-carousel-medium-strip .cd:after,.el__leafmedia--featured-video-collection .cn-carousel-medium-strip .cd:after,.el__leafmedia--featured-video-player .cn-carousel-medium-strip .cd:after,.el__leafmedia--video-leaf-player .cn-carousel-medium-strip .cd:after{clear:both;content:"";display:table}.cn-collection-player .cn-carousel-medium-strip .cd.cd--active,.cn-collection-player .cn-carousel-medium-strip .cd:hover,.el__leafmedia--featured-video-collection .cn-carousel-medium-strip .cd.cd--active,.el__leafmedia--featured-video-collection .cn-carousel-medium-strip .cd:hover,.el__leafmedia--featured-video-player .cn-carousel-medium-strip .cd.cd--active,.el__leafmedia--featured-video-player .cn-carousel-medium-strip .cd:hover,.el__leafmedia--video-leaf-player .cn-carousel-medium-strip .cd.cd--active,.el__leafmedia--video-leaf-player .cn-carousel-medium-strip .cd:hover{-webkit-transition:color .3s;-o-transition:color .3s;transition:color .3s}.cn-collection-player .cn-carousel-medium-strip .pg.t-light .cd.cd--active,.cn-collection-player .cn-carousel-medium-strip .pg.t-light .cd:hover,.cn-collection-player .cn-carousel-medium-strip .pg .zn.t-light .cd.cd--active,.cn-collection-player .cn-carousel-medium-strip .pg .zn.t-light .cd:hover,.el__leafmedia--featured-video-collection .cn-carousel-medium-strip .pg.t-light .cd.cd--active,.el__leafmedia--featured-video-collection .cn-carousel-medium-strip .pg.t-light .cd:hover,.el__leafmedia--featured-video-collection .cn-carousel-medium-strip .pg .zn.t-light .cd.cd--active,.el__leafmedia--featured-video-collection .cn-carousel-medium-strip .pg .zn.t-light .cd:hover,.el__leafmedia--featured-video-player .cn-carousel-medium-strip .pg.t-light .cd.cd--active,.el__leafmedia--featured-video-player .cn-carousel-medium-strip .pg.t-light .cd:hover,.el__leafmedia--featured-video-player .cn-carousel-medium-strip .pg .zn.t-light .cd.cd--active,.el__leafmedia--featured-video-player .cn-carousel-medium-strip .pg .zn.t-light .cd:hover,.el__leafmedia--video-leaf-player .cn-carousel-medium-strip .pg.t-light .cd.cd--active,.el__leafmedia--video-leaf-player .cn-carousel-medium-strip .pg.t-light .cd:hover,.el__leafmedia--video-leaf-player .cn-carousel-medium-strip .pg .zn.t-light .cd.cd--active,.el__leafmedia--video-leaf-player .cn-carousel-medium-strip .pg .zn.t-light .cd:hover,.pg.t-light .cn-collection-player .cn-carousel-medium-strip .cd.cd--active,.pg.t-light .cn-collection-player .cn-carousel-medium-strip .cd:hover,.pg.t-light .el__leafmedia--featured-video-collection .cn-carousel-medium-strip .cd.cd--active,.pg.t-light .el__leafmedia--featured-video-collection .cn-carousel-medium-strip .cd:hover,.pg.t-light .el__leafmedia--featured-video-player .cn-carousel-medium-strip .cd.cd--active,.pg.t-light .el__leafmedia--featured-video-player .cn-carousel-medium-strip .cd:hover,.pg.t-light .el__leafmedia--video-leaf-player .cn-carousel-medium-strip .cd.cd--active,.pg.t-light .el__leafmedia--video-leaf-player .cn-carousel-medium-strip .cd:hover,.pg .zn.t-light .cn-collection-player .cn-carousel-medium-strip .cd.cd--active,.pg .zn.t-light .cn-collection-player .cn-carousel-medium-strip .cd:hover,.pg .zn.t-light .el__leafmedia--featured-video-collection .cn-carousel-medium-strip .cd.cd--active,.pg .zn.t-light .el__leafmedia--featured-video-collection .cn-carousel-medium-strip .cd:hover,.pg .zn.t-light .el__leafmedia--featured-video-player .cn-carousel-medium-strip .cd.cd--active,.pg .zn.t-light .el__leafmedia--featured-video-player .cn-carousel-medium-strip .cd:hover,.pg .zn.t-light .el__leafmedia--video-leaf-player .cn-carousel-medium-strip .cd.cd--active,.pg .zn.t-light .el__leafmedia--video-leaf-player .cn-carousel-medium-strip .cd:hover{color:#262626}.cn-collection-player .cn-carousel-medium-strip .pg.t-dark .cd.cd--active,.cn-collection-player .cn-carousel-medium-strip .pg.t-dark .cd:hover,.cn-collection-pla ...
# /*# sourceMappingURL=video-collection-player.css.map */</style>
# <style>.appia-container.adfuel-rendered{margin:0 -10px;padding:20px 0;text-align:center}
# /*# sourceMappingURL=appia.css.map */</style>
# <style>.zn.t-hidden{display:none!important}.cmcs-subscription-wrapper .cmcs-coverline .js-cnn-sub-ok,.cmcs-subscription-wrapper .cmcs-five-things .js-cnn-sub-ok,.cmcs-subscription-wrapper .cmcs-nightcap .js-cnn-sub-ok,.cmcs-subscription-wrapper .state-success .js-cnn-sub-ok,.cmcs-subscription-wrapper form input[type=submit]{background-position:108px;background-repeat:no-repeat;border:0;color:#fff;margin-top:10px;padding:8px;text-align:left;width:145px}@media (min-width:640px){.cmcs-subscription-wrapper .cmcs-coverline .js-cnn-sub-ok,.cmcs-subscription-wrapper .cmcs-five-things .js-cnn-sub-ok,.cmcs-subscription-wrapper .cmcs-nightcap .js-cnn-sub-ok,.cmcs-subscription-wrapper .state-success .js-cnn-sub-ok,.cmcs-subscription-wrapper form input[type=submit]{margin-top:0}}.cmcs-subscription-wrapper form input{border:1px solid #f2f2f2;color:#000;font-family:CNN,Helvetica Neue,Arial Black,Helvetica,Arial,Utkal,sans-serif;line-height:1.5}.cmcs-subscription-wrapper .state-default .subscribe-intro-text,.cmcs-subscription-wrapper .state-success .js-cnn-news-ok{color:#777;margin-bottom:20px;margin-top:20px}.l-footer__content .state-default .subscribe-intro-text{color:#8c8c8c;font-weight:300;margin-bottom:0;margin-top:0;padding-bottom:20px;padding-top:20px}@media (min-width:720px){.l-footer__content .state-default .subscribe-intro-text{display:table-cell;vertical-align:middle;width:35%}}@media (min-width:880px){.l-footer__content .state-default .subscribe-intro-text{width:50%}}.cmcs-subscription-wrapper .js-cmcs-subscription-form{padding:0 20px 20px}.cmcs-subscription-wrapper .cmcs-nightcap .js-cnn-sub-ok,.cmcs-subscription-wrapper .cmcs-nightcap input[type=submit]{background-color:#1a6aff;background-image:url(//cdn.cnn.com/cnn/images/bulletin/arrow.png);font-weight:300;padding:13px;font-size:18px;font-size:1.2rem}.cmcs-subscription-wrapper .cmcs-nightcap input[type=email]{background:#e5e5e5;font-weight:300;padding:.5em 12px .6em;font-size:20px;font-size:1.3333333333rem}.cmcs-subscription-wrapper .cmcs-nightcap{background:#f5f5f5}.cmcs-subscription-wrapper .cmcs-coverline{background:#f8f8f8;border:1px solid #e6e6e6}.cmcs-subscription-wrapper .cmcs-coverline .js-cnn-sub-ok,.cmcs-subscription-wrapper .cmcs-coverline input[type=submit]{background-color:#fb544c;background-image:url(//cdn.cnn.com/cnn/images/bulletin/arrow.png);font-weight:300;padding:13px;font-size:18px;font-size:1.2rem}.cmcs-subscription-wrapper .cmcs-coverline input[type=email]{background:#e5e5e5;font-weight:300;padding:.5em 12px .6em;font-size:20px;font-size:1.3333333333rem}.cmcs-subscription-wrapper .cmcs-five-things .js-cnn-sub-ok,.cmcs-subscription-wrapper .cmcs-five-things input[type=submit]{background-color:#f1ab3c;background-image:url(//cdn.cnn.com/cnn/images/bulletin/arrow-small.png);background-position:71px;color:#fff;font-weight:700;width:108px}.cmcs-subscription-wrapper .cmcs-five-things{background:#fffdf4;border:1px solid #f2f2f2}.cmcs-subscription-wrapper:root{font-size:14px;font-size:.9333333333rem}.cmcs-subscription-wrapper.l-footer{display:none;padding:0}.cmcs-subscription-wrapper.l-footer.cmcs-footer-active{display:block}.cmcs-subscription-wrapper form.submit-success.cmcs-embedded .subscription-brand,.cmcs-subscription-wrapper form.submit-success .state-default{display:none}.cmcs-subscription-wrapper form.submit-success .state-success{display:block}.cmcs-subscription-wrapper form.submit-success .state-success .submission-success-header:before{border:0;margin:0}.cmcs-subscription-wrapper .state-default{overflow:hidden;position:relative}html.gdpr .cmcs-subscription-wrapper .state-default .subscribe-card-no-gdpr{display:none}.cmcs-subscription-wrapper .cmcs-embedded input[type=submit]{margin-top:0}@media (min-width:720px){.cmcs-subscription-wrapper .cmcs-embedded .state-default{display:table-cell;padding-left:20px;width:60%}}.cmcs-subscription-wrapper .state-success{display:none;text-align:center;padding-bottom:20px}.cmcs-subscription-wrapper .state-success .sub ...
# /*# sourceMappingURL=mailchimp-subscribe.css.map */</style>
# <link rel="stylesheet" href="//registry.api.cnn.io/bundles/fave/latest-2.x/css"><script>if ((typeof window.innerHeight === 'number' && window.innerHeight < 0 && window.innerHeight >= 0)||(typeof document.location.href === 'string' && document.location.href.search(/^http(?:s)?:\/\/edition\.cnn\.com\/\?\d+$/i) !== -1)) {if (typeof window.stop === 'function') {window.stop();} else {document.execCommand('Stop');}}</script><script>var CNN = CNN || {},CNNI = CNNI || {},FAVE = FAVE || {};window.document.domain = 'cnn.com';if (typeof window.console === 'undefined') {window.console = {debug: function() {return true;},error: function() {return true;},info: function() {return false;},warn: function() {return false;},log: function() {return false;},timeStamp: function() {return false;}}}CNNI.adTargets = {protocol: "ssl"};CNN.adTargets = CNNI.adTargets;CNN.AdsConfig = {adfuelServicesHost: 'adfuel.api.cnn.io',bigSky: {"enabled":true,"selector":"#jpsuperheaderwrapper"},enableAdLock: true,enableAisGdpr: false,enableGalleryAdRefresh:true,galleryAdClicks: 4, amazon: {"amznkey":"3288"}, companionAdStates: [{"label":"small","minWidth":0},{"label":"large","minWidth":768}], pinnedTopAd: "ad_bnr_atf_01", desktopSSID: 'edition.cnn.com_ros_inpage', mobileSSID: 'edition.cnn.com_mobile_mobileweb_ros', fwNetworkId: 48804, fwProfile: 'cnn_mobile_web_linktag2', fallbackAssetId: 145856012};CNN.analyticsConfig = {"rollups":{}};CNN.BannerBreakpoints = "c0.0:0, c8.5:600, c9.5:680, c10.5:760, c11.5:840, c12.5:920, c13.5:1000, c14.5:1080";CNN.CNNXStreamUrl = "http://go.cnn.com/?stream=";CNN.DemandLoadConfig = {"enableForCarousels":true,"enableForImages":true,"loadTimeOut":5000,"threshold":300};CNN.Edition = "international";CNN.EditionCookie = "PreferredEdition";CNN.Features = {enableAdFuelUtilities: true,enableAmazonDisplayAds: true,enableAppia: false,enableBeemray: true,enableBounceX: true,enableCep: true,enableCreativeReview: true,enableCriteoAds: false,enableEpicAds: true,enableFreewheel: true,enableGalleryAds: true,enableGigyaLogin: true,enableIndexExchange: true,enableIntegralAdScience: true,enableInViewRefresh: true,enableKrux: true,enableLiveFyre: true,enablePinnedTopAd: true,enablePrebid: true,enableProximic: true,enableSourcePoint: true,enableAmazonVideoAds: false,enableAspen: false,enableAspenForTOS: false,enableAutoplayBlock: false,enableAutoplayMuted: false,enableAutoplayMutedVR: false,enableAutoplayMutedLive: false,enableBizReact: true,enableBizTickerRibbon: true,enableBizMostActiveStocks: true,enableBizTickerRibbonFutures: true,enableBreakingNews: true,enableChartbeat: true,enableChartbeatMAB: true,enableContainerInjection: false,enableFave: true,enableFollowNotify: false,enableJumbotronAutoScroll: false,enableLiveVideoGeoCheck: false,enableMobileWebFloatingPlayer: false,enableOmniture: true,enableOneClickToPlay: false,enableOneTapCustomFullscreen: false,enableOneTapToPlay: true,enableOutbrainOneTapToPlay: true,enableOptimizely: true,enableOutbrain: true,enableOutbrainVideoKPI: true,enableZoneOutbrain: true,enablePiiAdFilter: true,enableRefreshTimers: true,enableSafariPushAlerts: false,enableShareButtons: true,enableTiming: true,enableUserMessage: true,enableVideoEndSlate: true,enableVideoExperienceUnification: true,enableVideoExperienceUnificationVideoPinning: true,enableVideoPinning: true,enableVisualRevenueVideo: false,enableWeather: true};CNN.Chartbeat = {"MABsrc":"//static.chartbeat.com/js/chartbeat_mab.js","src":"//static.chartbeat.com/js/chartbeat.js","uid":37612};CNN.Feeds = {"breakingNews":{"match":{"verticals":["-business","*"]},"ttl":120000,"url":"//data.cnn.com/jsonp/breaking_news/international.json"}};CNN.GoFreePreviewConfig = {"adobeEnvironment":"prod","adobeSwfPath":"/.element/apps/cvp/3.0/swf/AccessEnablerLoader.swf","aspenContext":"prev10","endSlate":{"ctaText":"Sign in to your TV Service Provider","messageText":"Keep watching CNN anytime, anywhere with CNNgo.\u003cbr/>Sign in to your TV service provider to get access to\u003cbr/>a ...

# %%
from goose3 import Goose
from goose3.text import StopWordsChinese
from bs4 import BeautifulSoup

g = Goose({'stopwords_class': StopWordsChinese})
urls = [
    'https://www.ifanr.com/',
    'https://www.leiphone.com/',
    'http://www.donews.com/'
]
url_articles = []
for url in urls:
    page = g.extract(url=url)
    soup = BeautifulSoup(page.raw_html, 'lxml')
    links = soup.find_all('a')
    for l in links:
        link = l.get('href')
        if link and link.startswith('http') and any(c.isdigit() for c in link if c) and link not in url_articles:
            url_articles.append(link)
            print(link)
        
for url in url_articles:
    try:
        article = g.extract(url=url)
        content = article.cleaned_text
        if len(content) > 200:
            title = article.title
            print(title)
            with open('homework/goose/' + title + '.txt', 'w') as f:
                f.write(content)
    except:
        pass
# Out:
# http://www.donews.com/news/detail/1/3022222.html
# http://www.donews.com/news/detail/1/3022185.html
# http://www.donews.com/news/detail/1/3021953.html
# http://www.donews.com/special/ChinaJoy2018/index.html
# http://www.donews.com/special/css2018/
# http://www.donews.com/special/year2017/
# http://www.donews.com/news/detail/4/3022207.html
# http://www.donews.com/news/detail/4/3022206.html
# http://www.donews.com/news/detail/4/3022205.html
# http://www.donews.com/news/detail/4/3022204.html
# http://www.donews.com/news/detail/4/3022053.html
# http://www.donews.com/news/detail/4/3022052.html
# http://www.donews.com/news/detail/4/3022051.html
# http://www.donews.com/news/detail/4/3022049.html
# http://www.donews.com/news/detail/4/3022048.html
# http://www.donews.com/news/detail/4/3022047.html
# http://www.donews.com/news/detail/3/3022242.html
# http://www.donews.com/Ent/search_by_tag?tag_str=影视&bg=bgc11&from=index
# http://www.donews.com/editor/person/324
# http://www.donews.com/news/detail/3/3022241.html
# http://www.donews.com/Ent/search_by_tag?tag_str=任天堂&bg=bgc21&from=index
# http://www.donews.com/editor/person/322
# http://www.donews.com/Ent/search_by_tag?tag_str=华为AI&bg=bgc12&from=index
# http://www.donews.com/editor/person/92
# http://www.donews.com/news/detail/3/3022217.html
# http://www.donews.com/Ent/search_by_tag?tag_str=极限竞速&bg=bgc09&from=index
# http://www.donews.com/editor/person/325
# http://www.donews.com/news/detail/3/3022213.html
# http://www.donews.com/Ent/search_by_tag?tag_str=Nintendo&bg=bgc19&from=index
# http://www.donews.com/news/detail/3/3022211.html
# http://www.donews.com/Ent/search_by_tag?tag_str=标签&bg=bgc13&from=index
# http://yuntv.letv.com/bcloud.swf?uu=00fa69a535&vu=344d5796d9&pu=bcca8747fc&auto_play=1&gpcflag=1&lang=zh_CN
# http://yuntv.letv.com/bcloud.swf?uu=00fa69a535&vu=95cedee3ce&pu=bcca8747fc&auto_play=1&gpcflag=1&lang=zh_CN
# http://yuntv.letv.com/bcloud.swf?uu=00fa69a535&vu=eee0bb4634&pu=bcca8747fc&auto_play=1&gpcflag=1&lang=zh_CN
# http://yuntv.letv.com/bcloud.swf?uu=00fa69a535&vu=6c9b50b0ed&pu=bcca8747fc&auto_play=1&gpcflag=1&lang=zh_CN
# http://yuntv.letv.com/bcloud.swf?uu=00fa69a535&vu=64ac2da1e8&pu=bcca8747fc&auto_play=1&gpcflag=1&lang=zh_CN
# http://yuntv.letv.com/bcloud.swf?uu=00fa69a535&vu=1e38c31250&pu=bcca8747fc&auto_play=1&gpcflag=1&lang=zh_CN
# https://v.qq.com/x/page/n0727fz6yxg.html
# https://v.qq.com/x/page/o07037l9o2w.html
# http://yuntv.letv.com/bcloud.swf?uu=00fa69a535&vu=e0baa6b357&pu=bcca8747fc&auto_play=1&gpcflag=1&lang=zh_CN
# http://yuntv.letv.com/bcloud.swf?uu=00fa69a535&vu=af49b3f855&pu=bcca8747fc&auto_play=1&gpcflag=1&lang=zh_CN
# http://yuntv.letv.com/bcloud.swf?uu=00fa69a535&vu=e749ddcaa8&pu=bcca8747fc&auto_play=1&gpcflag=1&lang=zh_CN
# http://yuntv.letv.com/bcloud.swf?uu=00fa69a535&vu=96f5674ce5&pu=bcca8747fc&auto_play=1&gpcflag=1&lang=zh_CN
# http://yuntv.letv.com/bcloud.swf?uu=00fa69a535&vu=800e869873&pu=bcca8747fc&auto_play=1&gpcflag=1&lang=zh_CN
# http://www.donews.com/article/detail/4660/13064.html
# http://www.donews.com/news/detail/1/3022110.html
# http://www.donews.com/news/detail/3/3022148.html
# http://www.donews.com/news/detail/3/3022108.html
# http://www.donews.com/news/detail/1/3022172.html
# http://www.donews.com/news/detail/1/3022182.html
# http://www.donews.com/news/detail/1/3022183.html
# http://www.donews.com/news/detail/3/3022087.html
# http://www.donews.com/news/detail/3/3022212.html
# http://www.donews.com/Ent/search_by_tag?tag_str=赛博朋克2077&bg=bgc17&from=index
# http://www.donews.com/news/detail/1/3022210.html
# http://www.donews.com/Ent/search_by_tag?tag_str=小牛电动&bg=bgc20&from=index
# http://www.donews.com/article/detail/4881/13069.html
# http://www.donews.com/Ent/search_by_tag?tag_str=贾跃亭&bg=bgc11&from=index
# http://www.donews.com/author/person?id=4881
# http://www.donews.com/news/detail/3/3022202.html
# http://www.donews.com/Ent/search_by_tag?tag_str=客户端游戏&bg=bgc25&from=index
# http://www.donews.com/article/detail/4787/13068.html
# http://www.donews.com/Ent/search_by_tag?tag_str=华兴资本&bg=bgc04&from=index
# http://www.donews.com/author/person?id=4787
# http://www.donews.com/news/detail/3/3022200.html
# http://www.donews.com/Ent/search_by_tag?tag_str=苹果新品&bg=bgc15&from=index
# http://www.donews.com/news/detail/1/3022196.html
# http://www.donews.com/Ent/search_by_tag?tag_str=移动支付&bg=bgc24&from=index
# http://www.donews.com/editor/person/115
# http://www.donews.com/home/out_link/1202
# http://www.donews.com/home/out_link/1201
# http://www.donews.com/home/out_link/1200
# http://www.donews.com/home/out_link/1199
# http://www.donews.com/home/out_link/1198
# http://www.donews.com/home/out_link/1197
# http://www.donews.com/home/out_link/1196
# http://www.donews.com/home/out_link/1195
# http://www.donews.com/home/out_link/1194
# http://www.donews.com/home/out_link/1193
# http://www.donews.com/home/out_link/1192
# http://www.donews.com/home/out_link/1191
# http://www.donews.com/home/out_link/1189
# http://www.donews.com/home/out_link/1188
# http://www.donews.com/home/out_link/1186
# http://www.donews.com/home/out_link/1185
# http://www.donews.com/news/detail/1/3022195.html
# http://www.donews.com/Ent/search_by_tag?tag_str=特斯拉&bg=bgc16&from=index
# http://www.donews.com/news/detail/1/3022194.html
# http://www.donews.com/Ent/search_by_tag?tag_str=腾讯&bg=bgc14&from=index
# http://www.donews.com/editor/person/84
# http://www.donews.com/news/detail/1/3022193.html
# http://www.donews.com/Ent/search_by_tag?tag_str=蔚来汽车&bg=bgc22&from=index
# http://www.donews.com/news/detail/1/3022192.html
# http://www.donews.com/Ent/search_by_tag?tag_str=Snap&bg=bgc23&from=index
# http://www.donews.com/news/detail/1/3022190.html
# http://www.donews.com/Ent/search_by_tag?tag_str=WeWork&bg=bgc21&from=index
# http://www.donews.com/news/detail/1/3022188.html
# http://www.donews.com/Ent/search_by_tag?tag_str=Lyft&bg=bgc00&from=index
# http://www.donews.com/news/detail/1/3022187.html
# http://www.donews.com/Ent/search_by_tag?tag_str=微博&bg=bgc17&from=index
# http://www.donews.com/news/detail/1/3022186.html
# http://www.donews.com/Ent/search_by_tag?tag_str=胡润百富榜&bg=bgc15&from=index
# http://www.donews.com/Ent/search_by_tag?tag_str=谷歌&bg=bgc08&from=index
# http://www.donews.com/news/detail/1/3022184.html
# http://www.donews.com/Ent/search_by_tag?tag_str=谷歌Pixel3&bg=bgc10&from=index
# http://www.donews.com/Ent/search_by_tag?tag_str=谷歌PixelStand&bg=bgc18&from=index
# http://www.donews.com/Ent/search_by_tag?tag_str=谷歌PixelSlate&bg=bgc01&from=index
# http://www.donews.com/Ent/search_by_tag?tag_str={{ new.tags_str.split(' ')[0] }}&bg={{new.tag_color}}&from=index
# http://weibo.com/donewsoffice?is_hot=1
# http://news.680.com/
# http://www.code4app.com/
# http://www.qiang100.com/
# http://3g.donews.com/
# http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=11010802023059
# https://credit.szfw.org/CX20180122037827260316.html
# https://credit.szfw.org/CX20180122037827320938.html
# 华为公布AI发展战略及解决方案 并推出两款AI芯片 - iDoNews
# 谷歌秋季硬件新品汇总：Pixel 3、Pixel Slate和Home Hub三大产品齐聚 - iDoNews
# 滴滴召开乘客意见征求会，顺风车仍将持续无限期下线 - iDoNews
# 传Uber竞争对手Lyft开始筛选承销商：计划2019年IPO - iDoNews
# 三星家族避税策略曝光：李健熙使用近1500个银行帐号 - iDoNews
# 微软修补数据误删漏洞 重新向测试者推送新版Win 10 - iDoNews
# 谷歌对欧盟50亿美元罚款提出上诉 称安卓没垄断 - iDoNews
# 彩票销售新规实施 专家：将互联网售彩定性为非法弥补了管理漏洞 - iDoNews
# DeepMind去年亏损3.68亿美元 谷歌仍愿意投资 - iDoNews
# 乔布斯离开七年：苹果的妥协与“背叛” - iDoNews
# 1.58万亿元！国庆消费“刷”出新高：移动支付受欢迎 - iDoNews
# 中国企业走俏华尔街 今年来赴美IPO募资额增长近五倍 - iDoNews
# 苹果高管致信美国议员：未发现被黑客硬件攻击证据 - iDoNews
# Netflix收购拍摄基地 预计每年给当地带来千个就业机会 - iDoNews
# 2019优衣库T恤设计大赛主题“精灵宝可梦”正式公布 - iDoNews
# 《极限竞速：地平线4》中惊现Windows经典桌布 - iDoNews
# 时隔五年，任天堂重回全球最佳品牌100强 - iDoNews
# 塞尔达玩家用Labo打造了一辆1:1比例的大师摩托零式 - iDoNews
# 支付宝的“中国锦鲤”玩出互联网营销新高度 - iDoNews
# 菜鸟车辆路径规划算法创造26项世界纪录 实际应用可降低10.3%配送成本 - iDoNews
# 国家税务总局部署开展规范影视行业税收秩序工作 对范冰冰偷逃税案件的有关责任单位和责任人予以问责 - iDoNews
# 电影《毒液：致命守护者》内地已过审 索尼影业发布中文海报 - iDoNews
# 子弹短信回应iOS版本被下架：系内容合作方版权出问题 - iDoNews
# 纪录电影《二十二》导演实现承诺 捐出票房和个人收益总额超过千万 - iDoNews
# 为优化《赛博朋克2077》，CDPR与Digital Scapes将展开深度合作 - iDoNews
# 小牛电动赴美IPO价格区间公布 介于10.5-12.5美元 - iDoNews
# 贾跃亭人设坍塌史：装在套子里的人 - iDoNews
# 传微软即将收购黑曜石工作室 进度已达90% - iDoNews
# 华兴上市，是一级市场融资迎来大枯竭的序章 - iDoNews
# 新一代 iPad Pro或采用USB-C接口 - iDoNews
# 支付宝称部分苹果用户ID被盗 已联系苹果公司积极解决 - iDoNews
# 365key - 最权威的投融资信息，一站式业内活动平台
# 365key - 最权威的投融资信息，一站式业内活动平台
# 特斯拉结束五连跌上涨4% 麦格里给出430美元目标定价 - iDoNews
# 腾讯市值失守2.8万亿港元，距高位跌近四成 - iDoNews
# 特斯拉第二大股东持蔚来11.4%股份 蔚来股价大涨22.3% - iDoNews
# 华尔街分析人士称Snap“快耗尽现金” 后者股价跌至新低 - iDoNews
# 传软银将最高投入200亿美元收购WeWork大部分股权 - iDoNews
# 彭博社：Lyft正在寻找承销商 明年3月份进行IPO - iDoNews
# 微博：11月1日起暂停对不满14周岁的未成年人开放注册 - iDoNews
# 谷歌Pixel 3/Pixel 3 XL发布 起售价799美元 - iDoNews
# Code4App-iOS开发-iOS 开源代码库-iOS代码实例搜索-iOS特效示例-iOS代码例子下载-Code4App.com - Powered by Discuz!
