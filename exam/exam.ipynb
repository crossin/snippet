# %%
data = [[2017, 940, 700, 74.46],
[2016, 940, 705, 75],
[2015, 942, 700, 74.3],
[2014, 939, 698, 74.3],
[2013, 912, 694, 76],
[2012, 915, 685, 75],
[2011, 933, 675, 72],
[2010, 946, 657, 69],
[2009, 1020, 629, 62],
[2008, 1050, 599, 57],
[2007, 1010, 566, 56],
[2006, 950, 546, 57],
[2005, 877, 504, 57],
[2004, 729, 447, 61],
[2003, 613, 382, 62],
[2002, 510, 320, 63],
[2001, 454, 268, 59],
[2000, 375, 221, 59],
[1999, 288, 160, 56],
[1998, 320, 108, 34],
[1997, 278, 100, 36],
[1996, 241, 97, 40],
[1995, 253, 93, 37],
[1994, 251, 90, 36],
[1993, 286, 98, 34],
[1992, 303, 75, 25],
[1991, 296, 62, 21],
[1990, 283, 61, 22],
[1989, 266, 60, 23],
[1988, 272, 67, 25],
[1987, 228, 62, 27],
[1986, 191, 57, 30],
[1985, 176, 62, 35],
[1984, 164, 48, 29],
[1983, 167, 39, 23],
[1982, 187, 32, 17],
[1981, 259, 28, 11],
[1980, 333, 28, 8],
[1979, 468, 28, 6],
[1978, 610, 40.2, 7],
[1977, 570, 27, 5]]

# %%
import numpy as np
arr = np.array(data)

# %%
from pyecharts import Bar, Line, Overlap

bar = Bar("历年报考人数与录取率")
bar.add("报考人数",arr[::-1,0] , arr[::-1,1])
bar.add("录取人数",arr[::-1,0] , arr[::-1,2])
line = Line()
line.add("录取率",arr[::-1,0] , arr[::-1,3]*10, line_width=3, line_color='green')
ol = Overlap()
ol.add(bar)
ol.add(line)
ol
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="02bd7de1c20f4b50b2f3b05ac2248488" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('02bd7de1c20f4b50b2f3b05ac2248488'));
# var option =  {
#     "title": [
#         {
#             "text": "\u5386\u5e74\u62a5\u8003\u4eba\u6570\u4e0e\u5f55\u53d6\u7387",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 151218,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u62a5\u8003\u4eba\u6570",
#             "data": [
#                 570.0,
#                 610.0,
#                 468.0,
#                 333.0,
#                 259.0,
#                 187.0,
#                 167.0,
#                 164.0,
#                 176.0,
#                 191.0,
#                 228.0,
#                 272.0,
#                 266.0,
#                 283.0,
#                 296.0,
#                 303.0,
#                 286.0,
#                 251.0,
#                 253.0,
#                 241.0,
#                 278.0,
#                 320.0,
#                 288.0,
#                 375.0,
#                 454.0,
#                 510.0,
#                 613.0,
#                 729.0,
#                 877.0,
#                 950.0,
#                 1010.0,
#                 1050.0,
#                 1020.0,
#                 946.0,
#                 933.0,
#                 915.0,
#                 912.0,
#                 939.0,
#                 942.0,
#                 940.0,
#                 940.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 151218
#         },
#         {
#             "type": "bar",
#             "name": "\u5f55\u53d6\u4eba\u6570",
#             "data": [
#                 27.0,
#                 40.2,
#                 28.0,
#                 28.0,
#                 28.0,
#                 32.0,
#                 39.0,
#                 48.0,
#                 62.0,
#                 57.0,
#                 62.0,
#                 67.0,
#                 60.0,
#                 61.0,
#                 62.0,
#                 75.0,
#                 98.0,
#                 90.0,
#                 93.0,
#                 97.0,
#                 100.0,
#                 108.0,
#                 160.0,
#                 221.0,
#                 268.0,
#                 320.0,
#                 382.0,
#                 447.0,
#                 504.0,
#                 546.0,
#                 566.0,
#                 599.0,
#                 629.0,
#                 657.0,
#                 675.0,
#                 685.0,
#                 694.0,
#                 698.0,
#                 700.0,
#                 705.0,
#                 700.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 151218
#         },
#         {
#             "type": "line",
#             "name": "\u5f55\u53d6\u7387",
#             "symbol": "emptyCircle",
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 50.0,
#                 70.0,
#                 60.0,
#                 80.0,
#                 110.0,
#                 170.0,
#                 230.0,
#                 290.0,
#                 350.0,
#                 300.0,
#                 270.0,
#                 250.0,
#                 230.0,
#                 220.0,
#                 210.0,
#                 250.0,
#                 340.0,
#                 360.0,
#                 370.0,
#                 400.0,
#                 360.0,
#                 340.0,
#                 560.0,
#                 590.0,
#                 590.0,
#                 630.0,
#                 620.0,
#                 610.0,
#                 570.0,
#                 570.0,
#                 560.0,
#                 570.0,
#                 620.0,
#                 690.0,
#                 720.0,
#                 750.0,
#                 760.0,
#                 743.0,
#                 743.0,
#                 750.0,
#                 744.5999999999999
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 3,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "green"
#                 }
#             },
#             "areaStyle": {},
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 151218,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u62a5\u8003\u4eba\u6570",
#                 "\u5f55\u53d6\u4eba\u6570",
#                 "\u5f55\u53d6\u7387"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",

# %%
data_born = [[124761, 123626, 122389, 121121, 119850, 118517, 117171, 115823, 114333, 112704, 111026, 109300, 107507, 105851, 104357, 103008, 101654, 100072, 98705, 97542, 96259, 94974, 93717, 92420, 90859, 89211, 87177, 85229, 82992, 80671, 78534, 76368, 74542, 72538, 70499, 69172, 67296, 65859, 66207, 67207, 65994], 
             [14.64, 15.64, 16.57, 16.98, 17.12, 17.70, 18.09, 18.24, 19.68, 21.06, 21.58, 22.37, 23.33, 22.43, 21.04, 19.90, 20.19, 22.28, 20.91, 18.21, 17.82, 18.25, 19.03, 20.01, 23.13, 24.95, 28.07, 29.92, 30.74, 33.59, 34.25, 35.75, 34.12, 35.21, 38.00, 39.34, 43.60, 37.22, 18.13, 20.86, 24.78]]
arr_born = np.array(data_born)
list_born = list((arr_born[0]*arr_born[1]/1000)[::-1])
list_born
# Out:
# [1635.33132,
#  1401.9380200000001,
#  1200.3329099999999,
#  2451.27198,
#  2934.1055999999999,
#  2721.2264800000003,
#  2678.962,
#  2554.0629800000002,
#  2543.3730399999999,
#  2730.1559999999999,
#  2689.7894999999999,
#  2709.7388900000001,
#  2551.1740800000002,
#  2550.05168,
#  2447.0583900000001,
#  2225.8144499999999,
#  2101.5686700000001,
#  1849.3242000000002,
#  1783.43451,
#  1733.2755,
#  1715.3353800000002,
#  1776.23982,
#  2063.92155,
#  2229.6041600000003,
#  2052.39426,
#  2049.8591999999999,
#  2195.6712799999996,
#  2374.2379300000002,
#  2508.1383099999994,
#  2445.0410000000002,
#  2395.9410799999996,
#  2373.5462399999997,
#  2250.0734400000001,
#  2112.6115199999999,
#  2119.6233900000002,
#  2097.7509,
#  2051.8320000000003,
#  2056.6345799999999,
#  2027.9857299999999,
#  1933.5106400000002,
#  1826.5010400000001]

# %%
from pyecharts import Bar, Line, Overlap

bar = Bar("历年报考人数与出生人数")
bar.add("报考人数",arr[::-1,0] , arr[::-1,1])
bar.add("出生人数",arr[::-1,0] , list_born)
bar
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="98d6f581d2f547d4a4b3cd07d7faddf7" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('98d6f581d2f547d4a4b3cd07d7faddf7'));
# var option =  {
#     "title": [
#         {
#             "text": "\u5386\u5e74\u62a5\u8003\u4eba\u6570\u4e0e\u51fa\u751f\u4eba\u6570",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 836979,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u62a5\u8003\u4eba\u6570",
#             "data": [
#                 570.0,
#                 610.0,
#                 468.0,
#                 333.0,
#                 259.0,
#                 187.0,
#                 167.0,
#                 164.0,
#                 176.0,
#                 191.0,
#                 228.0,
#                 272.0,
#                 266.0,
#                 283.0,
#                 296.0,
#                 303.0,
#                 286.0,
#                 251.0,
#                 253.0,
#                 241.0,
#                 278.0,
#                 320.0,
#                 288.0,
#                 375.0,
#                 454.0,
#                 510.0,
#                 613.0,
#                 729.0,
#                 877.0,
#                 950.0,
#                 1010.0,
#                 1050.0,
#                 1020.0,
#                 946.0,
#                 933.0,
#                 915.0,
#                 912.0,
#                 939.0,
#                 942.0,
#                 940.0,
#                 940.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 836979
#         },
#         {
#             "type": "bar",
#             "name": "\u51fa\u751f\u4eba\u6570",
#             "data": [
#                 1635.33132,
#                 1401.93802,
#                 1200.3329099999999,
#                 2451.27198,
#                 2934.1056,
#                 2721.2264800000003,
#                 2678.962,
#                 2554.06298,
#                 2543.37304,
#                 2730.156,
#                 2689.7895,
#                 2709.73889,
#                 2551.1740800000002,
#                 2550.05168,
#                 2447.05839,
#                 2225.81445,
#                 2101.56867,
#                 1849.3242000000002,
#                 1783.43451,
#                 1733.2755,
#                 1715.3353800000002,
#                 1776.23982,
#                 2063.92155,
#                 2229.6041600000003,
#                 2052.39426,
#                 2049.8592,
#                 2195.6712799999996,
#                 2374.2379300000002,
#                 2508.1383099999994,
#                 2445.041,
#                 2395.9410799999996,
#                 2373.5462399999997,
#                 2250.07344,
#                 2112.61152,
#                 2119.62339,
#                 2097.7509,
#                 2051.8320000000003,
#                 2056.63458,
#                 2027.9857299999999,
#                 1933.5106400000002,
#                 1826.50104
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 836979
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u62a5\u8003\u4eba\u6570",
#                 "\u51fa\u751f\u4eba\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 1977.0,
#                 1978.0,
#                 1979.0,
#                 1980.0,
#                 1981.0,
#                 1982.0,
#                 1983.0,
#                 1984.0,
#                 1985.0,
#                 1986.0,
#                 1987.0,
#                 1988.0,
#                 1989.0,
#                 1990.0,
#                 1991.0,
#                 1992.0,
#                 1993.0,
#                 1994.0,
#                 1995.0,
#                 1996.0,
#                 1997.0,
#                 1998.0,
#                 1999.0,
#                 2000.0,
#                 2001.0,
#                 2002.0,
#                 2003.0,
#                 2004.0,
#                 2005.0,
#                 2006.0,
#                 2007.0,
#                 2008.0,
#                 2009.0,
#                 2010.0,
#                 2011.0,
#                 2012.0,
#                 2013.0,
#                 2014.0,
#                 2015.0,
#                 2016.0,
#                 2017.0
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {

# %%
from pyecharts import Map  
  
data_prov = [('北京', 6.3), ('重庆', 25), ('上海', 5), ('天津', 5.5), ('河南', 98.38), ('广东', 75.8), ('山东', 59.2), ('安徽', 49.9), ('四川', 62), ('江苏', 33.15), ('河北', 48.64), ('湖北', 37.4), ('陕西', 31.9), ('湖南', 45.18), ('山西', 30.5), ('浙江', 30.6), ('甘肃', 27.3), ('广西', 40), ('江西', 38), ('福建', 20.09), ('辽宁', 18.5), ('贵州', 44), ('云南', 30), ('黑龙江', 19.04), ('内蒙古', 19.5), ('吉林', 15.03), ('新疆', 20.74), ('宁夏', 6.95), ('海南', 5.88), ('青海', 4), ('西藏', 2.53)]  
geo = Map("2018各省高考报名人数")
attr, value = geo.cast(data_prov)
geo.add("", attr, value, visual_range=[0, 80], is_visualmap=True, is_map_symbol_show=False)  
geo
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts/china'
#          }
#     });
# </script>
# <div id="06e0620889ec4fe1be5e3334665b220c" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts', 'china' ],function(ec){
# 	var myChart = ec.init(document.getElementById('06e0620889ec4fe1be5e3334665b220c'));
# var option =  {
#     "title": [
#         {
#             "text": "2018\u5404\u7701\u9ad8\u8003\u62a5\u540d\u4eba\u6570",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7018360,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 6.3
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 5.5
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 98.38
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 75.8
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 59.2
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 49.9
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 33.15
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 48.64
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 37.4
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 31.9
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 45.18
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 30.5
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 30.6
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 27.3
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 20.09
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 18.5
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 44
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 19.04
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 19.5
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 15.03
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 20.74
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 6.95
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 5.88
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 2.53
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": false
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 80,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": null
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "dimension": null,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart.setOption(option);
#
#     });
# </script>

# %%
data_prov_ad = [('湖南', 11.2), ('江西', 10.4), ('安徽', 14.2), ('广东', 11.2), ('河北', 14.55), ('湖北', 15.8), ('河南', 7.8), ('山西', 9.8), ('福建', 18.7), ('吉林', 12.4), ('重庆', 11.5), ('辽宁', 16.1), ('内蒙古', 14.03), ('甘肃', 15.22), ('黑龙江', 13.5), ('陕西', 14.6), ('宁夏', 19), ('新疆', 12.86), ('西藏', 11), ('青海', 15.2), ('四川', 10.6), ('云南', 10.85), ('广西', 8.44), ('贵州', 14.50), ('北京', 30.5), ('江苏', 12.10), ('山东', 10.6), ('天津', 24.1), ('上海', 21.8), ('浙江', 14)]
geo = Map("2018各省一本录取率")
attr, value = geo.cast(data_prov_ad)
geo.add("", attr, value, visual_range=[8, 20], is_visualmap=True, is_map_symbol_show=False)  
geo
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts/china'
#          }
#     });
# </script>
# <div id="dc11d8bb4e7644f5b1847bfd56ec3db2" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts', 'china' ],function(ec){
# 	var myChart = ec.init(document.getElementById('dc11d8bb4e7644f5b1847bfd56ec3db2'));
# var option =  {
#     "title": [
#         {
#             "text": "2018\u5404\u7701\u4e00\u672c\u5f55\u53d6\u7387",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1793964,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 11.2
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 10.4
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 14.2
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 11.2
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 14.55
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 15.8
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 7.8
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 9.8
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 18.7
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 12.4
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 11.5
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 16.1
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 14.03
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 15.22
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 13.5
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 14.6
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 12.86
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 15.2
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 10.6
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 10.85
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 8.44
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 14.5
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 30.5
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 12.1
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 10.6
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 24.1
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 21.8
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 14
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": false
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 8,
#         "max": 20,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": null
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "dimension": null,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart.setOption(option);
#
#     });
# </script>
